# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsa3809/machine-learning-specialization/blob/main/Scikit_Learn_for_Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

X = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y = np.array([0, 0, 0, 1, 1, 1])

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression()
lr_model.fit(X, y)

print("w1 and w2:", lr_model.coef_)
print("b:", lr_model.intercept_)
# Out:
# w1 and w2: [[0.90411349 0.73587543]]
# b: [-2.33371631]

# %%
y_pred = lr_model.predict(X)

print("Prediction on training set:", y_pred)

probabilities = lr_model.predict_proba(X)
print(probabilities)
# Out:
# Prediction on training set: [0 0 0 1 1 1]
# [[0.68521578 0.31478422]
#  [0.66679559 0.33320441]
#  [0.64785146 0.35214854]
#  [0.32157091 0.67842909]
#  [0.27963728 0.72036272]
#  [0.39889156 0.60110844]]

# %%
print("Accuracy on training set:", lr_model.score(X, y))
# Out:
# Accuracy on training set: 1.0
