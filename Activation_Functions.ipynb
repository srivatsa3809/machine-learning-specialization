# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsa3809/machine-learning-specialization/blob/main/Activation_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Clear out any broken files to prevent caching conflicts
import sys
# !rm -f lab_utils_common.py autils.py lab_utils_relu.py deeplearning.mplstyle
sys.modules.pop('lab_utils_common', None)
sys.modules.pop('autils', None)
sys.modules.pop('lab_utils_relu', None)

# 2. Download Course 2 Activation & ReLU Lab files from GitHub
# Using a public repo that hosts the Coursera ML Specialization files
# !wget -q "https://raw.githubusercontent.com/jxareas/Machine-Learning-Notebooks/master/2_Advanced_Learning_Algorithms/Week%202.%20Neural%20network%20training/lab_utils_common.py"
# !wget -q "https://raw.githubusercontent.com/jxareas/Machine-Learning-Notebooks/master/2_Advanced_Learning_Algorithms/Week%202.%20Neural%20network%20training/autils.py"
# !wget -q "https://raw.githubusercontent.com/jxareas/Machine-Learning-Notebooks/master/2_Advanced_Learning_Algorithms/Week%202.%20Neural%20network%20training/lab_utils_relu.py"
# !wget -q "https://raw.githubusercontent.com/jxareas/Machine-Learning-Notebooks/master/2_Advanced_Learning_Algorithms/Week%202.%20Neural%20network%20training/deeplearning.mplstyle"

# 3. Enable Colab's interactive widget framework
from google.colab import output
output.enable_custom_widget_manager()
# !pip install -q ipympl

# =====================================================================
# 4. RUN YOUR COURSE 2 RELU LAB IMPORTS
# =====================================================================
# Set the widget backend for interactive plots right before imports
# %matplotlib widget

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from matplotlib.widgets import Slider
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU
from tensorflow.keras.activations import linear, relu, sigmoid

# Apply style sheets
plt.style.use('./deeplearning.mplstyle')

# Course 2 specific local imports
from lab_utils_common import dlc
from autils import plt_act_trio
from lab_utils_relu import *

# Silence warnings to keep Colab clean
import warnings
warnings.simplefilter(action='ignore', category=UserWarning)
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)

print("🚀 Course 2 ReLU & Activations lab imports are fully loaded and functional!")

# %% [markdown]
# <a name="2"></a>
# ## 2 - ReLU Activation
# This week, a new activation was introduced, the Rectified Linear Unit (ReLU).
# $$ a = max(0,z) \quad\quad\text {# ReLU function} $$

# %%
plt_act_trio()

# %%
_ = plt_relu_ex()
