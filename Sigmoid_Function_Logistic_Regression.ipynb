# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsa3809/machine-learning-specialization/blob/main/Sigmoid_Function_Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Clear out any potential stale files to avoid caching conflicts
# !rm -f lab_utils_common.py plt_one_addpt_onclick.py deeplearning.mplstyle
import sys
sys.modules.pop('lab_utils_common', None)
sys.modules.pop('plt_one_addpt_onclick', None)

# 2. Download the exact Week 3 files needed for this classification lab
# !wget -q https://raw.githubusercontent.com/greyhatguy007/Machine-Learning-Specialization-Coursera/main/C1%20-%20Supervised%20Machine%20Learning%20-%20Regression%20and%20Classification/week3/Optional%20Labs/lab_utils_common.py
# !wget -q https://raw.githubusercontent.com/greyhatguy007/Machine-Learning-Specialization-Coursera/main/C1%20-%20Supervised%20Machine%20Learning%20-%20Regression%20and%20Classification/week3/Optional%20Labs/plt_one_addpt_onclick.py
# !wget -q https://raw.githubusercontent.com/greyhatguy007/Machine-Learning-Specialization-Coursera/main/C1%20-%20Supervised%20Machine%20Learning%20-%20Regression%20and%20Classification/week3/Optional%20Labs/deeplearning.mplstyle

# 3. Enable Colab's interactive widget framework
from google.colab import output
output.enable_custom_widget_manager()
# !pip install -q ipympl

# =====================================================================
# 4. RUN YOUR LAB IMPORTS
# =====================================================================
import numpy as np

# Use the widget backend for the interactive clicking interface
# %matplotlib widget
import matplotlib.pyplot as plt

# Import the specific functions for your classification notebook
from plt_one_addpt_onclick import plt_one_addpt_onclick
from lab_utils_common import draw_vthresh

# Apply style sheets
plt.style.use('./deeplearning.mplstyle')

print("🚀 Week 3 Classification imports are fully configured and ready!")

# %% [markdown]
# $g(z) = \frac{1}{1+e^{-z}}\tag{1}$

# %%
# Input is an array.
input_array = np.array([1,2,3])
exp_array = np.exp(input_array)

print("Input to exp:", input_array)
print("Output of exp:", exp_array)

# Input is a single number
input_val = 1
exp_val = np.exp(input_val)

print("Input to exp:", input_val)
print("Output of exp:", exp_val)

# %%
def sigmoid(z):
    """
    Compute the sigmoid of z

    Args:
        z (ndarray): A scalar, numpy array of any size.

    Returns:
        g (ndarray): sigmoid(z), with the same shape as z

    """

    g = 1/(1+np.exp(-z))

    return g

# %% [markdown]
# We take the linear regression formula + sigmoid function to generate the logistic regression formula: $$f(x) = \frac{1}{1 + e^{-(wx + b)}}$$

# %%
# Generate an array of evenly spaced values between -10 and 10
z_tmp = np.arange(-10,11)

# Use the function implemented above to get the sigmoid values
y = sigmoid(z_tmp)

# Code for pretty printing the two arrays next to each other
np.set_printoptions(precision=3)
print("Input (z), Output (sigmoid(z))")
print(np.c_[z_tmp, y])

# %%
# Plot z vs sigmoid(z)
fig,ax = plt.subplots(1,1,figsize=(5,3))
ax.plot(z_tmp, y, c="b")

ax.set_title("Sigmoid function")
ax.set_ylabel('sigmoid(z)')
ax.set_xlabel('z')
draw_vthresh(ax,0)

# %%
x_train = np.array([0., 1, 2, 3, 4, 5])
y_train = np.array([0,  0, 0, 1, 1, 1])

w_in = np.zeros((1))
b_in = 0

# %%
plt.close('all')
addpt = plt_one_addpt_onclick( x_train,y_train, w_in, b_in, logistic=True)
