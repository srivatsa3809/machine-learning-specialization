# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsa3809/machine-learning-specialization/blob/main/Week1_Cost_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Configure Git so it knows who you are
# !git config --global user.name "srivatsa3809"
# Make sure to replace this with your actual GitHub email:
# !git config --global user.email "shashsri123@gmail.com"

# 2. Rewrite the message of your last commit
# !git commit --amend -m "Week 1, Course 1, Cost Functions"

# 3. Push the corrected message to GitHub
# !git push --force
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# Download lab_utils_uni.py
# !wget -O lab_utils_uni.py https://raw.githubusercontent.com/mohadeseh-ghafoori/Coursera-Machine-Learning-Specialization/main/Supervised%20Machine%20Learning%20Regression%20and%20Classification/week1/lab_utils_uni.py

# Download deeplearning.mplstyle
# !wget -O deeplearning.mplstyle https://raw.githubusercontent.com/mohadeseh-ghafoori/Coursera-Machine-Learning-Specialization/main/Supervised%20Machine%20Learning%20Regression%20and%20Classification/week2/Optional%20Labs/deeplearning.mplstyle

# %%
# !wget -O deeplearning.mplstyle https://raw.githubusercontent.com/mohadeseh-ghafoori/Coursera-Machine-Learning-Specialization/main/Advanced%20Learning%20Algorithms/week2/Assignment/deeplearning.mplstyle

# %%
# !wget -O lab_utils_common.py https://raw.githubusercontent.com/mohadeseh-ghafoori/Coursera-Machine-Learning-Specialization/main/Supervised%20Machine%20Learning%20Regression%20and%20Classification/week1/lab_utils_common.py

# %%
import numpy as np
import matplotlib.pyplot as plt

# Commented out to avoid the backend error
# %matplotlib widget

# These will load successfully now!
from lab_utils_uni import plt_intuition, plt_stationary, plt_update_onclick, soup_bowl
plt.style.use('./deeplearning.mplstyle')

print("All imports ready to go!")

# %%
x_train = np.array([1.0, 2.0])           #(size in 1000 square feet)
y_train = np.array([300.0, 500.0])           #(price in 1000s of dollars)

# %% [markdown]
# These are the same training features as from before

# %% [markdown]
# # Cost Function Formula
#
# $$J(w,b) = \frac{1}{2m} \sum_{i=0}^{m-1} (f_{w,b}(x^{(i)}) - y^{(i)})^2$$
#
# Where:
# *   $f_{w,b}(x^{(i)}) = wx^{(i)} + b$ (Your model's prediction)
# *   $y^{(i)}$ (The actual target value)
# *   $m$ (The total number of training examples)

# %%
def compute_cost(x, y, w, b):
    """
    Computes the cost function for linear regression.

    Args:
      x (ndarray (m,)): Data, m examples
      y (ndarray (m,)): target values
      w,b (scalar)    : model parameters

    Returns
        total_cost (float): The cost of using w,b as the parameters for linear regression
               to fit the data points in x and y
    """
    # number of training examples
    m = x.shape[0]

    cost_sum = 0
    for i in range(m):
        f_wb = w * x[i] + b
        cost = (f_wb - y[i]) ** 2
        cost_sum = cost_sum + cost
    total_cost = (1 / (2 * m)) * cost_sum

    return total_cost

# %%
plt_intuition(x_train,y_train)

# %% [markdown]
# So you see here is that we want the minimum of the cost function and at that point, our line is at it's most accurate prediction

# %%
x_train = np.array([1.0, 1.7, 2.0, 2.5, 3.0, 3.2])
y_train = np.array([250, 300, 480,  430,   630, 730,])

# %% [markdown]
# We have now more data points rather than just 2

# %%
plt.close('all')
fig, ax, dyn_items = plt_stationary(x_train, y_train)
updater = plt_update_onclick(fig, ax, x_train, y_train, dyn_items)

# %%
soup_bowl()
