# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsa3809/machine-learning-specialization/blob/main/Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Clear out any old versions of these files to force a clean slate
# !rm -f lab_utils_common.py plt_one_addpt_onclick.py deeplearning.mplstyle
# !rm -rf Machine-Learning-Specialization-Coursera

# 2. Reset the Python import cache so it forgets the old Week 2 versions
import sys
sys.modules.pop('lab_utils_common', None)
sys.modules.pop('plt_one_addpt_onclick', None)

# 3. Download the correct, updated scripts from Week 3 (Classification)
# !wget -q https://raw.githubusercontent.com/greyhatguy007/Machine-Learning-Specialization-Coursera/main/C1%20-%20Supervised%20Machine%20Learning%20-%20Regression%20and%20Classification/week3/Optional%20Labs/lab_utils_common.py
# !wget -q https://raw.githubusercontent.com/greyhatguy007/Machine-Learning-Specialization-Coursera/main/C1%20-%20Supervised%20Machine%20Learning%20-%20Regression%20and%20Classification/week3/Optional%20Labs/plt_one_addpt_onclick.py
# !wget -q https://raw.githubusercontent.com/greyhatguy007/Machine-Learning-Specialization-Coursera/main/C1%20-%20Supervised%20Machine%20Learning%20-%20Regression%20and%20Classification/week3/Optional%20Labs/deeplearning.mplstyle

# 4. Setup Colab's interactive widget backend
from google.colab import output
output.enable_custom_widget_manager()
# !pip install -q ipympl

# =====================================================================
# 5. RUN IMPORTS
# =====================================================================
import numpy as np

# Enable interactive plots
# %matplotlib widget
import matplotlib.pyplot as plt

# This will now successfully pull plot_data from the freshly downloaded Week 3 file
from lab_utils_common import dlc, plot_data
from plt_one_addpt_onclick import plt_one_addpt_onclick

np.set_printoptions(precision=2)
plt.style.use('./deeplearning.mplstyle')

print("🎉 Old files cleared. Week 3 modules loaded successfully!")

# %%
x_train = np.array([0., 1, 2, 3, 4, 5])
y_train = np.array([0,  0, 0, 1, 1, 1])
X_train2 = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_train2 = np.array([0, 0, 0, 1, 1, 1])

# %%
pos = y_train == 1
neg = y_train == 0

fig,ax = plt.subplots(1,2,figsize=(8,3))
#plot 1, single variable
ax[0].scatter(x_train[pos], y_train[pos], marker='x', s=80, c = 'red', label="y=1")
ax[0].scatter(x_train[neg], y_train[neg], marker='o', s=100, label="y=0", facecolors='none',
              edgecolors=dlc["dlblue"],lw=3)

ax[0].set_ylim(-0.08,1.1)
ax[0].set_ylabel('y', fontsize=12)
ax[0].set_xlabel('x', fontsize=12)
ax[0].set_title('one variable plot')
ax[0].legend()

#plot 2, two variables
plot_data(X_train2, y_train2, ax[1])
ax[1].axis([0, 4, 0, 4])
ax[1].set_ylabel('$x_1$', fontsize=12)
ax[1].set_xlabel('$x_0$', fontsize=12)
ax[1].set_title('two variable plot')
ax[1].legend()
plt.tight_layout()
plt.show()

# %%
w_in = np.zeros((1))
b_in = 0
plt.close('all')
addpt = plt_one_addpt_onclick( x_train,y_train, w_in, b_in, logistic=False)
