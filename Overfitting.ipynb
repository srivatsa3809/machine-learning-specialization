# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsa3809/machine-learning-specialization/blob/main/Overfitting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Clear out any potential stale files to avoid caching conflicts
import sys
# !rm -f lab_utils_common.py plt_overfit.py deeplearning.mplstyle
sys.modules.pop('lab_utils_common', None)
sys.modules.pop('plt_overfit', None)

# 2. Download the exact Week 3 files needed for this overfitting lab
# !wget -q https://raw.githubusercontent.com/greyhatguy007/Machine-Learning-Specialization-Coursera/main/C1%20-%20Supervised%20Machine%20Learning%20-%20Regression%20and%20Classification/week3/Optional%20Labs/lab_utils_common.py
# !wget -q https://raw.githubusercontent.com/greyhatguy007/Machine-Learning-Specialization-Coursera/main/C1%20-%20Supervised%20Machine%20Learning%20-%20Regression%20and%20Classification/week3/Optional%20Labs/plt_overfit.py
# !wget -q https://raw.githubusercontent.com/greyhatguy007/Machine-Learning-Specialization-Coursera/main/C1%20-%20Supervised%20Machine%20Learning%20-%20Regression%20and%20Classification/week3/Optional%20Labs/deeplearning.mplstyle

# 3. Enable Colab's interactive widget framework (Crucial for this specific lab's sliders)
from google.colab import output as colab_output
colab_output.enable_custom_widget_manager()
# !pip install -q ipympl ipywidgets

# =====================================================================
# 4. RUN YOUR LAB IMPORTS
# =====================================================================
import numpy as np

# Use the widget backend for interactive slider plots
# %matplotlib widget
import matplotlib.pyplot as plt
from ipywidgets import Output
from plt_overfit import overfit_example, output

# Apply style sheets
plt.style.use('./deeplearning.mplstyle')

print("🚀 Overfitting lab imports and interactive widgets are fully loaded!")

# %%
plt.close("all")
display(output)
ofit = overfit_example(False)
