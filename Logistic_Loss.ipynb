# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsa3809/machine-learning-specialization/blob/main/Logistic_Loss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Clear out any potential stale files to avoid caching conflicts
# !rm -f lab_utils_common.py plt_logistic_loss.py deeplearning.mplstyle
import sys
sys.modules.pop('lab_utils_common', None)
sys.modules.pop('plt_logistic_loss', None)

# 2. Download the exact Week 3 files needed for this specific loss function lab
# Note: plt_logistic_loss.py depends internally on lab_utils_common.py, so we pull both!
# !wget -q https://raw.githubusercontent.com/greyhatguy007/Machine-Learning-Specialization-Coursera/main/C1%20-%20Supervised%20Machine%20Learning%20-%20Regression%20and%20Classification/week3/Optional%20Labs/lab_utils_common.py
# !wget -q https://raw.githubusercontent.com/greyhatguy007/Machine-Learning-Specialization-Coursera/main/C1%20-%20Supervised%20Machine%20Learning%20-%20Regression%20and%20Classification/week3/Optional%20Labs/plt_logistic_loss.py
# !wget -q https://raw.githubusercontent.com/greyhatguy007/Machine-Learning-Specialization-Coursera/main/C1%20-%20Supervised%20Machine%20Learning%20-%20Regression%20and%20Classification/week3/Optional%20Labs/deeplearning.mplstyle

# 3. Enable Colab's interactive widget framework (Crucial for the "soup bowl" 3D plots)
from google.colab import output
output.enable_custom_widget_manager()
# !pip install -q ipympl

# =====================================================================
# 4. RUN YOUR LAB IMPORTS
# =====================================================================
import numpy as np

# Use the widget backend for interactive 3D scaling and clicking
# %matplotlib widget
import matplotlib.pyplot as plt

# Import the specific functions from plt_logistic_loss
from plt_logistic_loss import plt_logistic_cost, plt_two_logistic_loss_curves, plt_simple_example
from plt_logistic_loss import soup_bowl, plt_logistic_squared_error

# Apply style sheets
plt.style.use('./deeplearning.mplstyle')

print("🚀 Cost function visualization imports are fully loaded and ready!")

# %%
soup_bowl()

# %%
x_train = np.array([0., 1, 2, 3, 4, 5],dtype=np.longdouble)
y_train = np.array([0,  0, 0, 1, 1, 1],dtype=np.longdouble)
plt_simple_example(x_train, y_train)

# %%
plt.close('all')
plt_logistic_squared_error(x_train,y_train)
plt.show()

# %%
plt_two_logistic_loss_curves()

# %%
plt.close('all')
cst = plt_logistic_cost(x_train,y_train)
